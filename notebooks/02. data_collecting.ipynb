# %% [markdown]
# # Import Library and Function.

# %% [markdown]
# Import the function that compiled the web scraping process from the notebook before, from the src folder.

# %%
import sys
src_path = "/home/er_bim/Indonesia_COE/src/"
sys.path.insert(0, src_path)

from website_scraping import COE_scrape

# %% [markdown]
# # Extract The Indonesia COE data from the website.

# %% [markdown]
# Extract and save the tables as csv to the local directory.

# %%
# Year 2021 data
COE_scrape('indonesia', '2021')

# Year 2022 data
COE_scrape('indonesia', '2022')

# Year 2023 data
COE_scrape('indonesia', '2023')
# Out:
#     Ranking  Score                                               Farm  \
# 0        1A  91.41                                       Ijen Lestari
# 1        1B  91.41                                       Ijen Lestari
# 2        2A  90.35                                           Wajamala
# 3        2B  90.35                                           Wajamala
# 4        3A  90.06                                        Angin-angin
# 5        3B  90.06                                        Angin-angin
# 6         4  90.06                                     Avarata Coffee
# 7         5  89.47                            Central Sumatera Coffee
# 8         6  89.35                 Wanoja Coffee Plot Hj. Eti Sumiati
# 9         7  89.21                                      Atang Jungket
# 10        8  89.15  Rantekarua Coffee Plantation PT. Sulotco Jaya ...
# 11        9  88.38                         PT. De Gayo Agri Indonesia
# 12       10  88.15                                    Finca De Berman
# 13       11  88.06                        Koperasi Ribang Gayo Musara
# 14       12  88.03                                      Pelage Coffee
# 15       13  87.97                                 Bengkolan Dua Farm
# 16       14  87.97                                         Blok Emper
# 17       15  87.82                   Wanoja Coffee Plot Satrea Amambi
# 18       16  87.65                      Wanoja Coffee Plot Ita Rosita
# 19       17  87.59                                        Weninggalih
# 20       18  87.47                                  Kian Mandiri Farm
# 21       19  87.35                                       Siluk Coffee
# 22       20  87.35                        Suket Mountain/Gunung Suket
# 23       21  87.32                                 Rukun Saudara Farm
# 24       22  87.24                                    Empus Reje Guru
# 25  TOTALS:    NaN                                                NaN
#
#           Weight (lb)     Price per lb  Total Price  \
# 0              396.83           $45.50   $18,055.77
# 1              391.19           $43.60   $17,055.88
# 2              330.69           $30.00    $9,920.70
# 3              295.11           $30.50    $9,000.86
# 4              298.51           $26.25    $7,835.89
# 5              264.55           $27.30    $7,222.22
# 6              582.50           $10.00    $5,825.00
# 7              773.16            $8.60    $6,649.18
# 8              568.48           $10.37    $5,895.14
# 9              581.18           $15.80    $9,182.64
# 10             571.53            $9.30    $5,315.23
# 11             573.95           $11.80    $6,772.61
# 12             608.65            $9.00    $5,477.85
# 13             723.51            $7.00    $5,064.57
# 14             571.00            $8.60    $4,910.60
# 15             584.22           $10.20    $5,959.04
# 16             574.88           $11.11    $6,386.92
# 17             584.53           $10.90    $6,371.38
# 18             566.19           $11.10    $6,284.71
# 19             578.14           $10.20    $5,897.03
# 20             621.44           $10.20    $6,338.69
# 21             898.03           $13.60   $12,213.21
# 22             908.30            $6.25    $5,676.88
# 23             588.37           $16.40    $9,649.27
# 24             577.39            $8.45    $4,878.95
# 25  Total lb 14012.33  Avg. $/lb 13.83  $193,840.18
#
#                                                 Buyer
# 0                       Orsir International Co., Ltd.
# 1   SAVAYA Coffee Market – USA WAVY Coffee Roaster...
# 2   Coffee Me Up (Korea), Slick Coffee Co., Coffee...
# 3   BIG BLACK BOX (Thailand), Casa Lapin, Koff&Bun...
# 4   BLACK GOLD COFFEE (TAIWAN), COFFEE PARTNER INT...
# 5                                          CHG（手多多咖啡）
# 6                               Coffee Beyond Borders
# 7                            List & Beisler LA BOHEME
# 8    SAVAYA COFFEE MARKET – USA LaB Coffee & Roasters
# 9                               Coffee Beyond Borders
# 10                 La Pluma & Bohemian, ESCUDO COFFEE
# 11                             Sulalat Coffee Trading
# 12                                 Wataru & Co., Ltd.
# 13                                 Wataru & Co., Ltd.
# 14                                 Wataru & Co., Ltd.
# 15                                 Wataru & Co., Ltd.
# 16                                    MUSEO Co., Ltd.
# 17                             M.I.Coffee Corporation
# 18                            Wataru for Voila Coffee
# 19                           SUPREMO COFFEE – Germany
# 20                                      Campos Coffee
# 21                              Coffee Beyond Borders
# 22                                 Wataru & Co., Ltd.
# 23                                   Solberg & Hansen
# 24  Cuppers of Korea, Woojongho Coffee, Imbarista,...
# 25                                                NaN

# %% [markdown]
# # Extract The Ethiopia and Thailand data.

# %% [markdown]
# Modify the function to separate the extracted data location from Indonesia COE data.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
PATH = '/home/er_bim/Indonesia_COE/data/other/'


def COE_scrape(c: str, 
               y: str, 
               save_file: bool = True,
               return_file: bool = True) -> pd.DataFrame:
    """This function extract a specific country and year of Cup of Excellence (COE) auctions data
    from its official website. The website's homepage URL is defined as the parent_url variable,
    while the specific country and year of auction are specified as c and y arguments rescpectively.
    The function will return the COE Auction Result table.
    The function will also save the COE Competition Result and COE Auction Result tables, and store it
    in the local, the folder directory path is specified outside the function.
    
    Args:
        c (str): Define a country listed in Cup of Excellence
        y (str): Define the year period of Coffee of Excellence award 
        save_file (bool, optional): The tables saved as csv. Defaults to True.
        return_file (bool, optional): Defaults to True.

    Returns:
        pd.DataFrame: The Cup of Excellence auction result table.
    """
    parent_url = 'https://allianceforcoffeeexcellence.org/'
    url = parent_url+c+'-'+y
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'lxml')
    tabs = soup.select('ul.vc_tta-tabs-list')[0]
    tabs_links = tabs.find_all('a')
    relative_links = [t.get("href") for t in tabs_links]
    table_urls = [url + '/' + l for l in relative_links]
    tables_Response = requests.get(table_urls[0])
    tables = pd.read_html(tables_Response.text, header = 0)
    competition_results = tables[0]
    auction_results = tables[1]
    
    if save_file:  
        competition_results.to_csv(PATH+c+'_'+y+'_'+'coffee.csv') 
        auction_results.to_csv(PATH+c+'_'+y+'_'+'auction.csv')  
    
    if return_file:
        return auction_results

# %%
COE_scrape('ethiopia', '2022')
# Out:
#       RANK           FARM  SCORE  Weight (lbs)                     Bid ($/lb)  \
# 0       1a         Legese  90.69         529.1                       $ 400.50
# 1       1b         Legese  90.69         529.1                       $ 400.00
# 2        2         Kenean  90.25         363.8                       $ 189.10
# 3       3a       A/ Temam  90.19        1190.0                        $ 53.11
# 4       3b       A/ Temam  90.19        1124.0                        $ 55.60
# 5        4         Bukato  90.17        1190.0                        $ 90.00
# 6        5         Samuel  90.08         628.3                        $ 58.50
# 7        6       Tilahune  89.92        1918.0                        $ 30.70
# 8        7          Wolde  89.78         529.1                        $ 51.99
# 9        8        Muluneh  89.56        1422.0                        $ 26.70
# 10       9          Abebe  89.36        1753.0                        $ 50.50
# 11      10           Nare  88.78        2017.0                        $ 20.21
# 12      11           Aman  88.44        1356.0                        $ 17.10
# 13      12  Yosefe Kasaye  88.44        1290.0                        $ 28.70
# 14      13         Abiyot  88.42        2249.0                        $ 15.00
# 15      14           Dush  88.33        1620.0                        $ 12.20
# 16      15         Legese  88.31         892.9                        $ 15.00
# 17      16    Butu Gelcha  88.22        1124.0                        $ 21.00
# 18      17       Yohannes  88.17        1157.0                        $ 20.10
# 19      18      Alemayehu  88.17         330.7                        $ 13.10
# 20      19  Genale Gamada  88.11         595.3                        $ 36.00
# 21      20      Sentayehu  88.11         859.8                        $ 29.10
# 22      21       Desalegn  88.06         925.9                        $ 11.00
# 23      22    Bukku Abele  88.03         727.5                        $ 11.00
# 24      23           Awol  87.92        1058.0                        $ 18.10
# 25      24           Fuad  87.92        2116.0                        $ 15.10
# 26      25        Tadesse  87.86        1984.0                        $ 21.20
# 27      26          Ayele  87.81         496.0                         $ 9.10
# 28      27         Gemeda  87.75        2116.0                        $ 16.60
# 29      28       Aberashe  87.28         694.5                         $ 9.00
# 30      29           Alem  87.17        1323.0                        $ 18.00
# 31      30           Geno  87.17       36538.9                         $ 8.60
# 32  Totals            NaN    NaN       72647.9  Auction Average $/lb.  $55.37
#
#                       Total Value ($)  \
# 0                        $ 211,904.55
# 1                        $ 211,640.00
# 2                         $ 68,794.58
# 3                         $ 63,200.90
# 4                         $ 62,494.40
# 5                        $ 107,100.00
# 6                         $ 36,755.55
# 7                         $ 58,882.60
# 8                         $ 27,507.91
# 9                         $ 37,967.40
# 10                        $ 88,526.50
# 11                        $ 40,763.57
# 12                        $ 23,187.60
# 13                        $ 12,338.13
# 14                        $ 19,350.00
# 15                        $ 27,437.80
# 16                        $ 24,300.00
# 17                        $ 18,750.90
# 18                        $ 22,592.40
# 19                        $ 15,156.70
# 20                        $ 11,905.20
# 21                        $ 17,323.23
# 22                         $ 9,457.80
# 23                        $ 10,184.90
# 24                        $ 13,167.75
# 25                        $ 15,975.80
# 26                        $ 44,859.20
# 27                        $ 18,054.40
# 28                         $ 8,233.60
# 29                        $ 19,044.00
# 30                        $ 12,501.00
# 31                        $ 11,377.80
# 32  Total Auction Value $1,370,736.17
#
#                                                Winner
# 0               LNK Coffee Trading DMCC for Lebunna弘顺
# 1       SAZA COFFEE ( Japan ) & Orsir Coffee (Taiwan)
# 2                              Sulalat Coffee Trading
# 3   Simple Kaffa The Coffe One, Kakalove (Taiwan),...
# 4                                   KALDI COFFEE FARM
# 5                              Sulalat Coffee Trading
# 6                                   SARUTAHIKO COFFEE
# 7                           Kyokuto Fadie Corporation
# 8                                  Blue Bottle Coffee
# 9   BEAN SUPER豆超國際 / 百啡有光 / 云境農莊 / 麟閣咖啡 / 樂波波珈琲 / ...
# 10                            Sulalat Coffee Trading.
# 11                             Linking Coffee & 步昂咖啡.
# 12                                 KAFFEBRENNERIET AS
# 13  Coffee Tech Ltd. C&B Coffee Roasters. Demitass...
# 14  意可坊咖啡 for Cut Hand Group (剁手咖啡群) & Captain Geo...
# 15                                       Keffa Coffee
# 16                                  Black Gold Coffee
# 17  Snow Beans Coffee, Japan Roasters Network by M...
# 18                      Orsir International Co., Ltd.
# 19                             Linking Coffee & 步昂咖啡.
# 20                             Sulalat Coffee Trading
# 21                 Nanjing Eco Farm Trading Co., Ltd.
# 22                                   Brulerie du Quai
# 23                                  Full Sweet Coffee
# 24                 Nanjing Eco Farm Trading Co., Ltd.
# 25                             Linking Coffee & 步昂咖啡.
# 26  Kakalove (Taiwan), Simple Kaffa The Coffe One,...
# 27                                 Wataru & Co., Ltd.
# 28                            Wataru for Voila Coffee
# 29                                 Wataru & Co., Ltd.
# 30                          Artist Hub Coffee Company
# 31                                      honu加藤珈琲店株式会社
# 32                  Total Auction Value $1,370,736.17

# %%
COE_scrape('thailand', '2023')
# Out:
#    Rank  Score                              Farm  Weight (lb) High Bid  \
# 0    1a  91.13           Coffee De Hmong Biofarm        79.76   $69.50
# 1    1b  91.13           Coffee De Hmong Biofarm        66.14   $73.30
# 2     2  89.50            Phala Akha Coffee Farm       153.71   $25.30
# 3     3  89.13                  Soft Coffee Farm       177.08   $45.00
# 4     4  88.93                  Cherpong village       153.18   $18.80
# 5     5  88.80     Amazingcoffee at Mae Chan Tai       154.94   $17.30
# 6     6  88.80                 Doi Pakgud coffee       170.51   $15.10
# 7     7  88.73                           DoiTung       165.08   $25.60
# 8     8  88.63             Ma Family Coffee Farm       158.42   $15.20
# 9     9  88.60                           Doi Nan       167.73   $12.10
# 10   10  88.37                      Heramon farm       158.51   $13.20
# 11   11  87.63  DoiTung – Scaling Project in Nan       164.73   $20.00
# 12   12  87.47          Follow Your Heart Coffee       161.47    $5.70
# 13   13  87.40                              Soyi       268.43   $12.80
# 14   14  87.30                        Karen Farm       170.68   $20.00
# 15   15  87.20                              Apae       310.15    $9.40
# 16   16  87.20                    Praiwan estate       261.25    $6.10
#
#    Total Price                                       Company name
# 0    $5,543.32  YN coffee, Vela Ethan International Co.,Ltd, C...
# 1    $4,848.06  CHG（手多多咖啡）、Tasty&Oracle（塔苏瑞）、BEAN SUPER豆超國際 – ...
# 2    $3,888.86                  Kyokuto Fadie Corporation – Japan
# 3    $7,968.60                          Cuppingpost – South Korea
# 4    $2,879.78  The Coffee Tree Roasters – United States of Am...
# 5    $2,680.46                   Kizuna Roaster & Co. – Hong Kong
# 6    $2,574.70                         Full Sweet Coffee – Taiwan
# 7    $4,226.05  KALDI COFFEE FARM (CAMEL COFFEE CO.,LTD.) – Japan
# 8    $2,407.98                Ryans Coffee Roasters – South Korea
# 9    $2,029.53  Mercanta The Coffee Hunters for Alchemist Sing...
# 10   $2,092.33                   Kizuna Roaster & Co. – Hong Kong
# 11   $3,294.60                                 La Cabra – Denmark
# 12     $920.38                         Wataru & Co., Ltd. – Japan
# 13   $3,435.90    K.V.N. Import Export (1991) Co.,Ltd. – Thailand
# 14   $3,413.60  SHRUB COFFEE ,FUKUSUKE COFFEE ROASTERY ,新田珈琲 a...
# 15   $2,915.41                        KAFFEBRENNERIET AS – Norway
# 16   $1,593.63                         Wataru & Co., Ltd. – Japan
